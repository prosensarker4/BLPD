# %% [markdown]
# # **Clone the Repository**

# %%
# !git clone https://github.com/prosensarker4/BLPD.git
# Out:
# Cloning into 'BLPD'...
# remote: Enumerating objects: 19044, done.
# remote: Total 19044 (delta 0), reused 0 (delta 0), pack-reused 19044 (from 1)
# Receiving objects: 100% (19044/19044), 488.68 MiB | 18.17 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# Updating files: 100% (19022/19022), done.

# %%
# !pip install ultralytics
import ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.7 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# # License Plate Detection (LPD) Model Validation Performance

# %%
from ultralytics import YOLO
# Load trained model
model = YOLO('/content/BLPD/LPD_Model.pt')

# Validate on test set AND save images with predictions
results = model.val(
    data='/content/BLPD/LPD_data.yaml',
    split='val',         # use test split
    save=False             # save images with bounding boxes
)

# print(results)
# Out:
# Ultralytics 8.4.63 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv12m summary (fused): 169 layers, 20,105,683 parameters, 0 gradients, 67.1 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 717.2±339.5 MB/s, size: 51.3 KB)
# val: Scanning /content/BLPD/LPD_Dataset/valid/labels... 425 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 425/425 1.9Kit/s 0.2s
# val: New cache created: /content/BLPD/LPD_Dataset/valid/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 240, len(boxes) = 464. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 27/27 1.7it/s 16.1s
#                    all        425        464      0.993       0.97      0.974      0.674
# ...

# %% [markdown]
# # License Plate Detection (LPD) Model Test Performance

# %%
from ultralytics import YOLO
# Load trained model
model = YOLO('/content/BLPD/LPD_Model.pt')

# Validate on test set AND save images with predictions
results = model.val(
    data='/content/BLPD/LPD_data.yaml',
    split='test',         # use test split
    save=False             # save images with bounding boxes
)

# print(results)
# Out:
# Ultralytics 8.4.63 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv12m summary (fused): 169 layers, 20,105,683 parameters, 0 gradients, 67.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1891.7±271.8 MB/s, size: 56.3 KB)
# val: Scanning /content/BLPD/LPD_Dataset/test/labels... 213 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 213/213 2.2Kit/s 0.1s
# val: New cache created: /content/BLPD/LPD_Dataset/test/labels.cache
# WARNING ⚠️ Box and segment counts should be equal, but got len(segments) = 121, len(boxes) = 226. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 14/14 1.6it/s 8.5s
#                    all        213        226      0.986      0.965      0.963      0.685
# ...

# %% [markdown]
# # License Plate Number Recognition (LPNR) Model Validation Performance

# %%
from ultralytics import YOLO
# Load trained model
model = YOLO('/content/BLPD/LPNR_Model.pt')

# Validate on test set AND save images with predictions
results = model.val(
    data='/content/BLPD/LPNR_data.yaml',
    split='val',         # use test split
    save=False             # save images with bounding boxes
)

# print(results)
# Out:
# Ultralytics 8.4.63 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv12n summary (fused): 159 layers, 2,623,679 parameters, 0 gradients, 6.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1000.4±207.0 MB/s, size: 37.6 KB)
# val: Scanning /content/BLPD/LPNR_Dataset/valid/labels... 1438 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1438/1438 1.9Kit/s 0.7s
# val: New cache created: /content/BLPD/LPNR_Dataset/valid/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 90/90 4.2it/s 21.6s
#                    all       1438      12488      0.952      0.905       0.95      0.768
#                      0        486        593      0.995      0.966      0.993      0.668
#                      1        931       1651      0.987       0.98      0.994      0.685
#                      2        597        756      0.996      0.962      0.991       0.66
# ...

# %%
from ultralytics import YOLO
# Load trained model
model = YOLO('/content/BLPD/LPNR_Model.pt')

# Validate on test set AND save images with predictions
results = model.val(
    data='/content/BLPD/LPNR_data.yaml',
    split='val',         # use test split
    save=False             # save images with bounding boxes
)

# print(results)
# Out:
# Ultralytics 8.4.63 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv12n summary (fused): 159 layers, 2,623,679 parameters, 0 gradients, 6.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1580.3±621.0 MB/s, size: 35.8 KB)
# val: Scanning /content/BLPD/LPNR_Dataset/valid/labels.cache... 1438 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1438/1438 402.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 90/90 4.8it/s 18.7s
#                    all       1438      12488      0.952      0.905       0.95      0.768
#                      0        486        593      0.995      0.966      0.993      0.668
#                      1        931       1651      0.987       0.98      0.994      0.685
#                      2        597        756      0.996      0.962      0.991       0.66
#                      3        546        645      0.995      0.965      0.994      0.691
# ...

# %%
from ultralytics import YOLO
# Load trained model
model = YOLO('/content/BLPD/LPNR_Model.pt')

# Validate on test set AND save images with predictions
results = model.val(
    data='/content/BLPD/LPNR_data.yaml',
    split='test',         # use test split
    save=False             # save images with bounding boxes
)

# print(results)
# Out:
# Ultralytics 8.4.63 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv12n summary (fused): 159 layers, 2,623,679 parameters, 0 gradients, 6.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1598.5±704.0 MB/s, size: 56.9 KB)
# val: Scanning /content/BLPD/LPNR_Dataset/test/labels... 721 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 721/721 2.0Kit/s 0.4s
# val: New cache created: /content/BLPD/LPNR_Dataset/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 46/46 3.1it/s 14.6s
#                    all        721       6292       0.95      0.898      0.949      0.767
#                      0        234        280      0.996      0.939      0.985      0.663
#                      1        448        781      0.999      0.956      0.993      0.667
#                      2        292        365       0.99      0.964      0.992      0.665
# ...
